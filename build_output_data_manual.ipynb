# %% [markdown]
# # Underwriting Output Data Builder (Manual Paths)
#
# This notebook runs the same processing pipeline as `build_output_data.py`.
#
# Update the input and output paths in the next cell, then run all cells.

# %%
from pathlib import Path

# Manual configuration (edit these two lines)
INPUT_FILE = Path("data/auto_issuance_synthetic_1year_10000rows.xlsx")
OUTPUT_FOLDER = Path(".")

print("INPUT_FILE:", INPUT_FILE.resolve())
print("OUTPUT_FOLDER:", OUTPUT_FOLDER.resolve())
# Out:
# INPUT_FILE: /Users/rituparnapaldas/Documents/Exl_POC/underWrittingIssueance_2/underWrittingIssueance_2/data/auto_issuance_synthetic_1year_10000rows.xlsx
# OUTPUT_FOLDER: /Users/rituparnapaldas/Documents/Exl_POC/underWrittingIssueance_2/underWrittingIssueance_2

# %%
from build_output_data import run_pipeline

if not INPUT_FILE.exists():
    raise FileNotFoundError(f"Input file not found: {INPUT_FILE}")

manifest = run_pipeline(INPUT_FILE, OUTPUT_FOLDER)
manifest
# Out:
# {'generated_at': '2026-05-21T19:35:18',
#  'output_dir': '/Users/rituparnapaldas/Documents/Exl_POC/underWrittingIssueance_2/underWrittingIssueance_2',
#  'tables': [{'name': 'fact_cases',
#    'file': 'fact_cases.csv',
#    'rows': 10000,
#    'columns': 182},
#   {'name': 'fact_hold_events',
#    'file': 'fact_hold_events.csv',
#    'rows': 4842,
#    'columns': 9},
#   {'name': 'agg_monthly_tat_bucket',
#    'file': 'agg_monthly_tat_bucket.csv',
#    'rows': 37,
#    'columns': 3},
#   {'name': 'agg_monthly_holds_by_tat_bucket',
#    'file': 'agg_monthly_holds_by_tat_bucket.csv',
#    'rows': 37,
#    'columns': 4},
#   {'name': 'agg_hold_reason_impact',
#    'file': 'agg_hold_reason_impact.csv',
#    'rows': 6,
#    'columns': 4},
#   {'name': 'agg_top_brokers',
#    'file': 'agg_top_brokers.csv',
#    'rows': 10,
#    'columns': 3},
#   {'name': 'agg_top_account_analyst_7plus',
#    'file': 'agg_top_account_analyst_7plus.csv',
#    'rows': 10,
#    'columns': 3},
#   {'name': 'agg_top_underwriter_7plus',
#    'file': 'agg_top_underwriter_7plus.csv',
#    'rows': 10,
#    'columns': 3},
#   {'name': 'agg_top_rater_7plus',
#    'file': 'agg_top_rater_7plus.csv',
#    'rows': 10,
#    'columns': 3},
#   {'name': 'agg_top_7plus_onholdreason',
#    'file': 'agg_top_7plus_onholdreason.csv',
#    'rows': 5,
#    'columns': 3},
#   {'name': 'agg_top_7plus_bgi',
#    'file': 'agg_top_7plus_bgi.csv',
#    'rows': 4,
#    'columns': 3},
#   {'name': 'agg_top_7plus_lob',
#    'file': 'agg_top_7plus_lob.csv',
#    'rows': 3,
#    'columns': 3},
#   {'name': 'agg_top_7plus_state',
#    'file': 'agg_top_7plus_state.csv',
#    'rows': 5,
#    'columns': 3}]}

# %%
import pandas as pd

manifest_path = OUTPUT_FOLDER / "manifest.json"
tables = pd.read_json(manifest_path)["tables"] if manifest_path.exists() else []

if manifest_path.exists():
    import json
    with open(manifest_path, "r", encoding="utf-8") as f:
        manifest_json = json.load(f)
    pd.DataFrame(manifest_json.get("tables", []))
else:
    print("manifest.json not found in output folder")

# %% [markdown]
# ## Output Files
#
# After running, you should get:
# - `fact_cases.csv`
# - `fact_hold_events.csv`
# - `agg_*.csv` files for charts/KPIs
# - `manifest.json`
#
# Use these outputs in Streamlit (`Processed Output Folder`) and in Power BI.
